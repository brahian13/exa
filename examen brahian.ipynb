# %% [markdown]
# EXAMEN II  de Computacion 2

# %%
import pandas as pd
import numpy as np

# %%
por = pd.read_excel('data/porcino.xlsx')

# %%
mu = pd.read_csv('data/music.csv')

# %%
tt = pd.read_csv('data/titanic.csv')

# %%
uni = pd.read_csv('data/w_university_r.csv')

# %% [markdown]
# Pregunta 1
#
# Sobre el archivo calidad del porcino en chile 'porcino.xlsx'¿Cuantos procinos hembra hay en la region 'Maule' son en total?

# %%
por
# Out:
#         ID  Espesor Lomo\n  (m.m)  Porcentaje Magro\n CM (%)    Sexo  \
# 0      NaN                    NaN                        NaN     NaN
# 1      1.0                   64.4                       55.8   MACHO
# 2      2.0                   64.0                       57.9   MACHO
# 3      3.0                   56.4                       58.8   MACHO
# 4      4.0                   69.2                       54.6   MACHO
# ..     ...                    ...                        ...     ...
# 496  496.0                   80.8                       54.5  HEMBRA
# 497  497.0                   73.2                       55.6  HEMBRA
# 498  498.0                   66.4                       56.1  HEMBRA
# 499  499.0                   70.0                       57.4  HEMBRA
# 500  500.0                   73.6                       56.5  HEMBRA
#
#             Region Calidad de la carne  Peso Canal Caliente \n (PCC- Kg)  \
# ...

# %%
hem = por[por['Sexo']=='HEMBRA']
hem
# Out:
#         ID  Espesor Lomo\n  (m.m)  Porcentaje Magro\n CM (%)    Sexo  \
# 20    20.0                   64.4                       57.7  HEMBRA
# 31    31.0                   76.8                       58.0  HEMBRA
# 35    35.0                   67.6                       58.7  HEMBRA
# 46    46.0                   64.8                       52.3  HEMBRA
# 115  115.0                   71.6                       58.9  HEMBRA
# ..     ...                    ...                        ...     ...
# 496  496.0                   80.8                       54.5  HEMBRA
# 497  497.0                   73.2                       55.6  HEMBRA
# 498  498.0                   66.4                       56.1  HEMBRA
# 499  499.0                   70.0                       57.4  HEMBRA
# 500  500.0                   73.6                       56.5  HEMBRA
#
#         Region Calidad de la carne  Peso Canal Caliente \n (PCC- Kg)  \
# ...

# %%
hem_y_re = por[(por['Sexo']=='HEMBRA')&(por['Region']== 'Maule')]
hem_y_re
# Out:
#         ID  Espesor Lomo\n  (m.m)  Porcentaje Magro\n CM (%)    Sexo Region  \
# 128  128.0                   77.6                       57.8  HEMBRA  Maule
# 361  361.0                   64.0                       56.6  HEMBRA  Maule
# 362  362.0                   57.2                       53.2  HEMBRA  Maule
#
#     Calidad de la carne  Peso Canal Caliente \n (PCC- Kg)  \
# 128          Execelente                              94.5
# 361          Execelente                              79.3
# 362            Estandar                              72.5
#
#      Peso Canal Refrigerada (PCR - Kg)
# 128                               92.6
# 361                               77.2
# 362                               71.1

# %% [markdown]
# **Respuesta = 3 row**

# %% [markdown]
# Pregunta 2
#
# Sobre el Archivo de sobrevivientes del titanic 'titanic.csv'¿Cuantas personas de 38 años sobrevivieron?

# %%
tt
# Out:
#      Count  PassengerId  Survived  Pclass  \
# 0        1            1      Died       3
# 1        1            2  Survived       1
# 2        1            3  Survived       3
# 3        1            4  Survived       1
# 4        1            5      Died       3
# ..     ...          ...       ...     ...
# 886      1          887      Died       2
# 887      1          888  Survived       1
# 888      1          889      Died       3
# 889      1          890  Survived       1
# 890      1          891      Died       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %%
sur38= tt[(tt['Survived']=='Survived')&(tt['Age']== 38 )]
sur38
# Out:
#      Count  PassengerId  Survived  Pclass  \
# 1        1            2  Survived       1
# 25       1           26  Survived       3
# 61       1           62  Survived       1
# 224      1          225  Survived       1
# 716      1          717  Survived       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 25   Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38.0      1
# 61                                 Icard, Miss. Amelie  female  38.0      0
# 224                       Hoyt, Mr. Frederick Maxfield    male  38.0      1
# 716                      Endres, Miss. Caroline Louise  female  38.0      0
#
#      Parch    Ticket      Fare Cabin Embarked
# 1        0  PC 17599   71.2833   C85        C
# 25       5    347077   31.3875   NaN        S
# 61       0    113572   80.0000   B28      NaN
# 224      0     19943   90.0000   C93        S
# ...

# %% [markdown]
# **Respuesta = 5 row**

# %% [markdown]
# Pregunta 3
#
# Sobre el Archivo clasificacio Mundial de UNiversidades 'w_university_r.csv'¿Cuantas Universidades de Cyrus aparecen?

# %%
uni
# Out:
#       World Rank                                        Institution  \
# 0              1                                 Harvard University
# 1              2              Massachusetts Institute of Technology
# 2              3                                Stanford University
# 3              4                            University of Cambridge
# 4              5                               University of Oxford
# ...          ...                                                ...
# 1995        1996                           Bharathidasan University
# 1996        1997                     Federal University of Maranhão
# 1997        1998        Jiangxi University of Finance and Economics
# 1998        1999                             University of Tarapacá
# 1999        2000  National Institute of Mental Health and Neuros...
#
#             Location  National Rank Education Rank Employability Rank  \
# 0                USA              1              1                  1
# ...

# %%
uni.isnull().sum()
# Out:
# World Rank            0
# Institution           0
# Location              0
# National Rank         0
# Education Rank        0
# Employability Rank    0
# Faculty Rank          0
# Research Rank         0
# Score                 0
# dtype: int64

# %% [markdown]
# **Respuesta = No hay nulos**

# %% [markdown]
# Pregunta 4
#
# Sobre el Archivo Ingresos millones de dolares   Formatos Musicales 'music.csv' ¿En el año 2019, Cual formato tiene el valor mas alto de 'Revenue'?

# %%
mu
# Out:
#      Year     Format  Revenue [m$]
# 0    1973        DVD           0.0
# 1    1973      Other           0.0
# 2    1973      Tapes        2941.0
# 3    1973   Download           0.0
# 4    1973  Streaming           0.0
# ..    ...        ...           ...
# 379  2020   Download         653.0
# 380  2020  Streaming       10075.0
# 381  2020   Cassette           0.0
# 382  2020      Vinyl         626.0
# 383  2020         CD         484.0
#
# [384 rows x 3 columns]

# %%
año = mu[mu['Year']== 2019]
año
# Out:
#      Year     Format  Revenue [m$]
# 368  2019        DVD           1.3
# 369  2019      Other         333.0
# 370  2019      Tapes           0.0
# 371  2019   Download         810.0
# 372  2019  Streaming        8992.0
# 373  2019   Cassette           0.0
# 374  2019      Vinyl         492.0
# 375  2019         CD         639.0

# %% [markdown]
# **Respuesta = 372 / 2019 / Streaming / 8992.0**

# %% [markdown]
# Pregunta 5
#
# Sobre el Archivo Calidad de Porcino en chile 'procino.xlsx'¿Cuantos porcinos Macho tiene la calidad de carne 'Estandar'?

# %%
por
# Out:
#         ID  Espesor Lomo\n  (m.m)  Porcentaje Magro\n CM (%)    Sexo  \
# 0      NaN                    NaN                        NaN     NaN
# 1      1.0                   64.4                       55.8   MACHO
# 2      2.0                   64.0                       57.9   MACHO
# 3      3.0                   56.4                       58.8   MACHO
# 4      4.0                   69.2                       54.6   MACHO
# ..     ...                    ...                        ...     ...
# 496  496.0                   80.8                       54.5  HEMBRA
# 497  497.0                   73.2                       55.6  HEMBRA
# 498  498.0                   66.4                       56.1  HEMBRA
# 499  499.0                   70.0                       57.4  HEMBRA
# 500  500.0                   73.6                       56.5  HEMBRA
#
#             Region Calidad de la carne  Peso Canal Caliente \n (PCC- Kg)  \
# ...

# %%
mach_estan = por[(por['Sexo']=='MACHO')&(por['Calidad de la carne']== 'Estandar')]
mach_estan
# Out:
#         ID  Espesor Lomo\n  (m.m)  Porcentaje Magro\n CM (%)   Sexo  \
# 4      4.0                   69.2                       54.6  MACHO
# 6      6.0                   60.8                       55.0  MACHO
# 9      9.0                   58.0                       50.4  MACHO
# 12    12.0                   53.2                       54.0  MACHO
# 24    24.0                   54.4                       53.9  MACHO
# ..     ...                    ...                        ...    ...
# 446  446.0                   65.6                       54.6  MACHO
# 450  450.0                   62.8                       54.0  MACHO
# 474  474.0                   60.0                       54.9  MACHO
# 475  475.0                   74.0                       53.1  MACHO
# 483  483.0                   66.8                       54.5  MACHO
#
#             Region Calidad de la carne  Peso Canal Caliente \n (PCC- Kg)  \
# 4    Metropolitana            Estandar                              88.6
# ...

# %% [markdown]
# **Respuesta = 203 rows**

# %% [markdown]
# Pregunta 6
#
# Sobre el Archivo calidad del Porcino en Chile 'porcino.xlsx'¿Cuantos porcinos Machos de la Region 'O'Higgin' son en total?

# %%
Higgin = por[(por['Sexo']=='MACHO')&(por['Region']== 'O´Higgins')]
Higgin
# Out:
#         ID  Espesor Lomo\n  (m.m)  Porcentaje Magro\n CM (%)   Sexo  \
# 1      1.0                   64.4                       55.8  MACHO
# 8      8.0                   57.6                       56.5  MACHO
# 13    13.0                   60.0                       56.3  MACHO
# 15    15.0                   53.6                       58.1  MACHO
# 16    16.0                   62.8                       56.7  MACHO
# ..     ...                    ...                        ...    ...
# 478  478.0                   69.6                       57.0  MACHO
# 479  479.0                   71.6                       55.4  MACHO
# 482  482.0                   63.2                       55.9  MACHO
# 483  483.0                   66.8                       54.5  MACHO
# 489  489.0                   66.0                       55.5  MACHO
#
#         Region Calidad de la carne  Peso Canal Caliente \n (PCC- Kg)  \
# 1    O´Higgins          Execelente                              85.9
# ...

# %% [markdown]
# **Respuesta = 308 rows**

# %% [markdown]
# Pregunta 7
#
# Sobre el Archivo Sobrevivientes del Titanic 'titanic.csv' ¿Cuantos valores nulos tiene?

# %%
tt.isnull()
# Out:
#      Count  PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  \
# 0    False        False     False   False  False  False  False  False  False
# 1    False        False     False   False  False  False  False  False  False
# 2    False        False     False   False  False  False  False  False  False
# 3    False        False     False   False  False  False  False  False  False
# 4    False        False     False   False  False  False  False  False  False
# ..     ...          ...       ...     ...    ...    ...    ...    ...    ...
# 886  False        False     False   False  False  False  False  False  False
# 887  False        False     False   False  False  False  False  False  False
# 888  False        False     False   False  False  False   True  False  False
# 889  False        False     False   False  False  False  False  False  False
# 890  False        False     False   False  False  False  False  False  False
#
#      Ticket   Fare  Cabin  Embarked
# ...

# %%
tt.isnull().sum()
# Out:
# Count            0
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
tt.isnull().sum().sum()
# Out:
# 866

# %% [markdown]
# **Respuesta = 866 nulos en total**

# %% [markdown]
# Pregunta 8
#
# Sobre el Archivo clasificacio Mundial de UNiversidades 'w_university_r.csv'¿Cual es el 'Score' de la segunda mejor universidad de Perú en aparecer ?

# %%
uni
# Out:
#       World Rank                                        Institution  \
# 0              1                                 Harvard University
# 1              2              Massachusetts Institute of Technology
# 2              3                                Stanford University
# 3              4                            University of Cambridge
# 4              5                               University of Oxford
# ...          ...                                                ...
# 1995        1996                           Bharathidasan University
# 1996        1997                     Federal University of Maranhão
# 1997        1998        Jiangxi University of Finance and Economics
# 1998        1999                             University of Tarapacá
# 1999        2000  National Institute of Mental Health and Neuros...
#
#             Location  National Rank Education Rank Employability Rank  \
# 0                USA              1              1                  1
# ...

# %%
per2 = uni[uni['Location']=='Peru']
per2
# Out:
#       World Rank                             Institution Location  \
# 1505        1506    Cayetano Heredia Peruvian University     Peru
# 1580        1581  Pontifical Catholic University of Peru     Peru
#
#       National Rank Education Rank Employability Rank Faculty Rank  \
# 1505              1              -                  -            -
# 1580              2              -               1339            -
#
#      Research Rank  Score
# 1505          1437   67.7
# 1580          1506   67.3

# %% [markdown]
# **Respuesta = La Pontifical Catholic University of Peru es la segunda mejor unversidad de Perú con 67.3 de score**

# %% [markdown]
# Pregunta 9
#
# Sobre el Archivo Sobrevivientes del Titanic 'titanic.csv' ¿Cuantos varones sobrevivieron ?

# %%
tt
# Out:
#      Count  PassengerId  Survived  Pclass  \
# 0        1            1      Died       3
# 1        1            2  Survived       1
# 2        1            3  Survived       3
# 3        1            4  Survived       1
# 4        1            5      Died       3
# ..     ...          ...       ...     ...
# 886      1          887      Died       2
# 887      1          888  Survived       1
# 888      1          889      Died       3
# 889      1          890  Survived       1
# 890      1          891      Died       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %%
sobr_var = tt[(tt['Survived']=='Survived')&(tt['Sex']== 'male')]
sobr_var
# Out:
#      Count  PassengerId  Survived  Pclass                             Name  \
# 17       1           18  Survived       2     Williams, Mr. Charles Eugene
# 21       1           22  Survived       2            Beesley, Mr. Lawrence
# 23       1           24  Survived       1     Sloper, Mr. William Thompson
# 36       1           37  Survived       3                 Mamee, Mr. Hanna
# 55       1           56  Survived       1                Woolner, Mr. Hugh
# ..     ...          ...       ...     ...                              ...
# 838      1          839  Survived       3                  Chip, Mr. Chang
# 839      1          840  Survived       1             Marechal, Mr. Pierre
# 857      1          858  Survived       1           Daly, Mr. Peter Denis
# 869      1          870  Survived       3  Johnson, Master. Harold Theodor
# 889      1          890  Survived       1            Behr, Mr. Karl Howell
#
#       Sex   Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# ...

# %% [markdown]
# **Respuesta = 109 rows**

# %% [markdown]
# Pregunta 10
#
# Sobre el Archivo Ingresos millones de dolares Formatos Musicales 'music.csv'¿Cuantos valores nulos tiene?

# %%
mu.isnull()
# Out:
#       Year  Format  Revenue [m$]
# 0    False   False         False
# 1    False   False         False
# 2    False   False         False
# 3    False   False         False
# 4    False   False         False
# ..     ...     ...           ...
# 379  False   False         False
# 380  False   False         False
# 381  False   False         False
# 382  False   False         False
# 383  False   False         False
#
# [384 rows x 3 columns]

# %%
mu.isnull().sum()
# Out:
# Year            0
# Format          0
# Revenue [m$]    0
# dtype: int64

# %% [markdown]
# **Respuesta = 0 nulos**

# %% [markdown]
# Pregunta 11
#
# Sobre el Archivo clasificacio Mundial de UNiversidades 'w_university_r.csv' ¿Cual es el valor de 'Employability Rank' mas alto de universidad de chile en aparecer ?

# %%
uni
# Out:
#       World Rank                                        Institution  \
# 0              1                                 Harvard University
# 1              2              Massachusetts Institute of Technology
# 2              3                                Stanford University
# 3              4                            University of Cambridge
# 4              5                               University of Oxford
# ...          ...                                                ...
# 1995        1996                           Bharathidasan University
# 1996        1997                     Federal University of Maranhão
# 1997        1998        Jiangxi University of Finance and Economics
# 1998        1999                             University of Tarapacá
# 1999        2000  National Institute of Mental Health and Neuros...
#
#             Location  National Rank Education Rank Employability Rank  \
# 0                USA              1              1                  1
# ...

# %%
chi = uni[uni['Location']=='Chile']
chi
# Out:
#       World Rank                                   Institution Location  \
# 384          385       Pontifical Catholic University of Chile    Chile
# 430          431                           University of Chile    Chile
# 822          823                      University of Concepción    Chile
# 870          871     Federico Santa María Technical University    Chile
# 1169        1170                       Andrés Bello University    Chile
# 1232        1233                   Austral University of Chile    Chile
# 1376        1377                 University of Santiago, Chile    Chile
# 1420        1421  Pontifical Catholic University of Valparaíso    Chile
# 1448        1449                     University of La Frontera    Chile
# 1623        1624                      University of Valparaíso    Chile
# 1627        1628              Catholic University of the North    Chile
# 1723        1724                     Diego Portales University    Chile
# ...

# %% [markdown]
# **Respuesta = vemos que el mas alto de Employability Rank es 1629 de Andrés Bello University**

# %% [markdown]
# Pregunta 12
#
# Sobre el Archivo clasificacio Mundial de UNiversidades 'w_university_r.csv' ¿Cuantas universidades de chile aparecen?

# %%
chi = uni[uni['Location']=='Chile']
chi
# Out:
#       World Rank                                   Institution Location  \
# 384          385       Pontifical Catholic University of Chile    Chile
# 430          431                           University of Chile    Chile
# 822          823                      University of Concepción    Chile
# 870          871     Federico Santa María Technical University    Chile
# 1169        1170                       Andrés Bello University    Chile
# 1232        1233                   Austral University of Chile    Chile
# 1376        1377                 University of Santiago, Chile    Chile
# 1420        1421  Pontifical Catholic University of Valparaíso    Chile
# 1448        1449                     University of La Frontera    Chile
# 1623        1624                      University of Valparaíso    Chile
# 1627        1628              Catholic University of the North    Chile
# 1723        1724                     Diego Portales University    Chile
# ...

# %% [markdown]
# **Respuesta = Aparecen 16 universidades**

# %% [markdown]
# Pregunta 13
#
# Sobre el Archivo Calidad de Porcino en chile 'procino.xlsx' ¿Cuantos porcinos tiene la calidad de carne 'Estandar'?

# %%
por
# Out:
#         ID  Espesor Lomo\n  (m.m)  Porcentaje Magro\n CM (%)    Sexo  \
# 0      NaN                    NaN                        NaN     NaN
# 1      1.0                   64.4                       55.8   MACHO
# 2      2.0                   64.0                       57.9   MACHO
# 3      3.0                   56.4                       58.8   MACHO
# 4      4.0                   69.2                       54.6   MACHO
# ..     ...                    ...                        ...     ...
# 496  496.0                   80.8                       54.5  HEMBRA
# 497  497.0                   73.2                       55.6  HEMBRA
# 498  498.0                   66.4                       56.1  HEMBRA
# 499  499.0                   70.0                       57.4  HEMBRA
# 500  500.0                   73.6                       56.5  HEMBRA
#
#             Region Calidad de la carne  Peso Canal Caliente \n (PCC- Kg)  \
# ...

# %%
est = por[por['Calidad de la carne']=='Estandar']
est
# Out:
#         ID  Espesor Lomo\n  (m.m)  Porcentaje Magro\n CM (%)    Sexo  \
# 4      4.0                   69.2                       54.6   MACHO
# 6      6.0                   60.8                       55.0   MACHO
# 9      9.0                   58.0                       50.4   MACHO
# 12    12.0                   53.2                       54.0   MACHO
# 24    24.0                   54.4                       53.9   MACHO
# ..     ...                    ...                        ...     ...
# 483  483.0                   66.8                       54.5   MACHO
# 486  486.0                   68.8                       55.0  HEMBRA
# 490  490.0                   72.4                       55.0  HEMBRA
# 493  493.0                   73.2                       52.9  HEMBRA
# 496  496.0                   80.8                       54.5  HEMBRA
#
#             Region Calidad de la carne  Peso Canal Caliente \n (PCC- Kg)  \
# ...

# %% [markdown]
# **Respuesta = 230 rows**

# %% [markdown]
# Pregunta 14
#
# Sobre el Archivo clasificacio Mundial de UNiversidades 'w_university_r.csv' ¿Cual es el 'Score' de la mejor Universidad de Chile en aparecer?

# %%
uni
# Out:
#       World Rank                                        Institution  \
# 0              1                                 Harvard University
# 1              2              Massachusetts Institute of Technology
# 2              3                                Stanford University
# 3              4                            University of Cambridge
# 4              5                               University of Oxford
# ...          ...                                                ...
# 1995        1996                           Bharathidasan University
# 1996        1997                     Federal University of Maranhão
# 1997        1998        Jiangxi University of Finance and Economics
# 1998        1999                             University of Tarapacá
# 1999        2000  National Institute of Mental Health and Neuros...
#
#             Location  National Rank Education Rank Employability Rank  \
# 0                USA              1              1                  1
# ...

# %%
chi_may= uni[uni['Location']=='Chile']
chi_may
# Out:
#       World Rank                                   Institution Location  \
# 384          385       Pontifical Catholic University of Chile    Chile
# 430          431                           University of Chile    Chile
# 822          823                      University of Concepción    Chile
# 870          871     Federico Santa María Technical University    Chile
# 1169        1170                       Andrés Bello University    Chile
# 1232        1233                   Austral University of Chile    Chile
# 1376        1377                 University of Santiago, Chile    Chile
# 1420        1421  Pontifical Catholic University of Valparaíso    Chile
# 1448        1449                     University of La Frontera    Chile
# 1623        1624                      University of Valparaíso    Chile
# 1627        1628              Catholic University of the North    Chile
# 1723        1724                     Diego Portales University    Chile
# ...

# %% [markdown]
# **Respuesta = Es 75.5 de Pontifical Catholic University of Chile**

# %% [markdown]
# Pregunta 15
#
# Sobre el Archivo Calidad de Porcino en chile 'procino.xls' ¿Cuantos porcinos hembra de la region 'Metropolitana'son en total?

# %%
por
# Out:
#         ID  Espesor Lomo\n  (m.m)  Porcentaje Magro\n CM (%)    Sexo  \
# 0      NaN                    NaN                        NaN     NaN
# 1      1.0                   64.4                       55.8   MACHO
# 2      2.0                   64.0                       57.9   MACHO
# 3      3.0                   56.4                       58.8   MACHO
# 4      4.0                   69.2                       54.6   MACHO
# ..     ...                    ...                        ...     ...
# 496  496.0                   80.8                       54.5  HEMBRA
# 497  497.0                   73.2                       55.6  HEMBRA
# 498  498.0                   66.4                       56.1  HEMBRA
# 499  499.0                   70.0                       57.4  HEMBRA
# 500  500.0                   73.6                       56.5  HEMBRA
#
#             Region Calidad de la carne  Peso Canal Caliente \n (PCC- Kg)  \
# ...

# %%
metropo  = por[(por['Sexo']=='HEMBRA')&(por['Region']== 'Metropolitana')]
metropo
# Out:
#         ID  Espesor Lomo\n  (m.m)  Porcentaje Magro\n CM (%)    Sexo  \
# 485  485.0                   70.8                       57.5  HEMBRA
# 486  486.0                   68.8                       55.0  HEMBRA
# 487  487.0                   74.8                       58.8  HEMBRA
# 488  488.0                   57.6                       55.7  HEMBRA
#
#             Region Calidad de la carne  Peso Canal Caliente \n (PCC- Kg)  \
# 485  Metropolitana          Execelente                              92.1
# 486  Metropolitana            Estandar                              82.0
# 487  Metropolitana          Execelente                              83.5
# 488  Metropolitana          Execelente                              89.0
#
#      Peso Canal Refrigerada (PCR - Kg)
# 485                               90.2
# 486                               80.6
# 487                               81.3
# 488                               64.9

# %% [markdown]
# **Respuesta = son en total 4**

# %% [markdown]
# Pregunta 16
#
# Sobre el Archivo Sobrevivientes del Titanic 'titanic.csv' ¿Cuantos varones murieron?

# %%
tt
# Out:
#      Count  PassengerId  Survived  Pclass  \
# 0        1            1      Died       3
# 1        1            2  Survived       1
# 2        1            3  Survived       3
# 3        1            4  Survived       1
# 4        1            5      Died       3
# ..     ...          ...       ...     ...
# 886      1          887      Died       2
# 887      1          888  Survived       1
# 888      1          889      Died       3
# 889      1          890  Survived       1
# 890      1          891      Died       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %%
var_muertos = tt[(tt['Sex']== 'male')&(tt['Survived']=='Died')]
var_muertos
# Out:
#      Count  PassengerId Survived  Pclass                            Name  \
# 0        1            1     Died       3         Braund, Mr. Owen Harris
# 4        1            5     Died       3        Allen, Mr. William Henry
# 5        1            6     Died       3                Moran, Mr. James
# 6        1            7     Died       1         McCarthy, Mr. Timothy J
# 7        1            8     Died       3  Palsson, Master. Gosta Leonard
# ..     ...          ...      ...     ...                             ...
# 881      1          882     Died       3              Markun, Mr. Johann
# 883      1          884     Died       2   Banfield, Mr. Frederick James
# 884      1          885     Died       3          Sutehall, Mr. Henry Jr
# 886      1          887     Died       2           Montvila, Rev. Juozas
# 890      1          891     Died       3             Dooley, Mr. Patrick
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %% [markdown]
# **Respuesta = 468 rows**

# %% [markdown]
# Pregunta 17
#
# Sobre el Archivo Sobrevivientes del Titanic 'titanic.csv' ¿Cuantas mujeres de 38 sobrevivieron?

# %%
tt
# Out:
#      Count  PassengerId  Survived  Pclass  \
# 0        1            1      Died       3
# 1        1            2  Survived       1
# 2        1            3  Survived       3
# 3        1            4  Survived       1
# 4        1            5      Died       3
# ..     ...          ...       ...     ...
# 886      1          887      Died       2
# 887      1          888  Survived       1
# 888      1          889      Died       3
# 889      1          890  Survived       1
# 890      1          891      Died       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %%
mu_sur38= tt[(tt['Survived']=='Survived')&(tt['Age']== 38)&(tt['Sex']=='female')]
mu_sur38
# Out:
#      Count  PassengerId  Survived  Pclass  \
# 1        1            2  Survived       1
# 25       1           26  Survived       3
# 61       1           62  Survived       1
# 716      1          717  Survived       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 25   Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38.0      1
# 61                                 Icard, Miss. Amelie  female  38.0      0
# 716                      Endres, Miss. Caroline Louise  female  38.0      0
#
#      Parch    Ticket      Fare Cabin Embarked
# 1        0  PC 17599   71.2833   C85        C
# 25       5    347077   31.3875   NaN        S
# 61       0    113572   80.0000   B28      NaN
# 716      0  PC 17757  227.5250   C45        C

# %% [markdown]
# **Respuesta = solo 4**

# %% [markdown]
# Pregunta 18
#
# Sobre el Archivo Calidad de Porcino en chile 'procino.xls' ¿Cuantos porcinos hemnra de la region 'O'Higgin' son en total?

# %%
por
# Out:
#         ID  Espesor Lomo\n  (m.m)  Porcentaje Magro\n CM (%)    Sexo  \
# 0      NaN                    NaN                        NaN     NaN
# 1      1.0                   64.4                       55.8   MACHO
# 2      2.0                   64.0                       57.9   MACHO
# 3      3.0                   56.4                       58.8   MACHO
# 4      4.0                   69.2                       54.6   MACHO
# ..     ...                    ...                        ...     ...
# 496  496.0                   80.8                       54.5  HEMBRA
# 497  497.0                   73.2                       55.6  HEMBRA
# 498  498.0                   66.4                       56.1  HEMBRA
# 499  499.0                   70.0                       57.4  HEMBRA
# 500  500.0                   73.6                       56.5  HEMBRA
#
#             Region Calidad de la carne  Peso Canal Caliente \n (PCC- Kg)  \
# ...

# %%
he_higg = por[(por['Sexo']=='HEMBRA')&(por['Region']== 'O´Higgins')]
he_higg
# Out:
#         ID  Espesor Lomo\n  (m.m)  Porcentaje Magro\n CM (%)    Sexo  \
# 20    20.0                   64.4                       57.7  HEMBRA
# 31    31.0                   76.8                       58.0  HEMBRA
# 35    35.0                   67.6                       58.7  HEMBRA
# 115  115.0                   71.6                       58.9  HEMBRA
# 116  116.0                   75.6                       60.0  HEMBRA
# ..     ...                    ...                        ...     ...
# 496  496.0                   80.8                       54.5  HEMBRA
# 497  497.0                   73.2                       55.6  HEMBRA
# 498  498.0                   66.4                       56.1  HEMBRA
# 499  499.0                   70.0                       57.4  HEMBRA
# 500  500.0                   73.6                       56.5  HEMBRA
#
#         Region Calidad de la carne  Peso Canal Caliente \n (PCC- Kg)  \
# ...

# %% [markdown]
# **Respuesta = 106 rows**

# %% [markdown]
# Pregunta 19
#
# Sobre el Archivo Ingresos millones de dolares Formatos Musicales 'music.csv' ¿El 'Format' = Streaming en que año obtuvo el valor mas alto en Revenue[m]?

# %%
mu
# Out:
#      Year     Format  Revenue [m$]
# 0    1973        DVD           0.0
# 1    1973      Other           0.0
# 2    1973      Tapes        2941.0
# 3    1973   Download           0.0
# 4    1973  Streaming           0.0
# ..    ...        ...           ...
# 379  2020   Download         653.0
# 380  2020  Streaming       10075.0
# 381  2020   Cassette           0.0
# 382  2020      Vinyl         626.0
# 383  2020         CD         484.0
#
# [384 rows x 3 columns]

# %%
stream = mu[(mu['Format']=='Streaming')]
stream
# Out:
#      Year     Format  Revenue [m$]
# 4    1973  Streaming           0.0
# 12   1974  Streaming           0.0
# 20   1975  Streaming           0.0
# 28   1976  Streaming           0.0
# 36   1977  Streaming           0.0
# 44   1978  Streaming           0.0
# 52   1979  Streaming           0.0
# 60   1980  Streaming           0.0
# 68   1981  Streaming           0.0
# 76   1982  Streaming           0.0
# 84   1983  Streaming           0.0
# 92   1984  Streaming           0.0
# 100  1985  Streaming           0.0
# 108  1986  Streaming           0.0
# 116  1987  Streaming           0.0
# 124  1988  Streaming           0.0
# 132  1989  Streaming           0.0
# 140  1990  Streaming           0.0
# 148  1991  Streaming           0.0
# 156  1992  Streaming           0.0
# 164  1993  Streaming           0.0
# 172  1994  Streaming           0.0
# 180  1995  Streaming           0.0
# 188  1996  Streaming           0.0
# 196  1997  Streaming           0.0
# 204  1998  Streaming           0.0
# ...

# %% [markdown]
# **Respuesta = El año con mas Revenue [m$] es el 2020**

# %% [markdown]
# Pregunta 20
#
# Sobre el Archivo Ingresos millones de dolares Formatos Musicales 'music.csv' ¿El 'Format' = Vinyl en que año obtuvo el valor mas alto en Revenue[m]?

# %%
stream_v = mu[(mu['Format']=='Vinyl')]
stream_v
# Out:
#      Year Format  Revenue [m$]
# 6    1973  Vinyl        8371.0
# 14   1974  Vinyl        8137.0
# 22   1975  Vinyl        8161.0
# 30   1976  Vinyl        8679.0
# 38   1977  Vinyl       10422.0
# 46   1978  Vinyl       10851.0
# 54   1979  Vinyl        8594.0
# 62   1980  Vinyl        7695.0
# 70   1981  Vinyl        7397.0
# 78   1982  Vinyl        5922.0
# 86   1983  Vinyl        5089.0
# 94   1984  Vinyl        4602.0
# 102  1985  Vinyl        3756.0
# 110  1986  Vinyl        2860.0
# 118  1987  Vinyl        2270.0
# 126  1988  Vinyl        1559.0
# 134  1989  Vinyl         703.0
# 142  1990  Vinyl         358.0
# 150  1991  Vinyl         177.0
# 158  1992  Vinyl         147.0
# 166  1993  Vinyl         111.0
# 174  1994  Vinyl         114.0
# 182  1995  Vinyl         122.0
# 190  1996  Vinyl         139.0
# 198  1997  Vinyl         111.0
# 206  1998  Vinyl          95.0
# 214  1999  Vinyl          93.0
# 222  2000  Vinyl          81.0
# 230  2001  Vinyl          86.0
# ...

# %% [markdown]
# **Respuesta = El mayor es 1978 con 10851.0**
